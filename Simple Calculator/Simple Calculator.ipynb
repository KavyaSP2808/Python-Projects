# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/Python-Projects/blob/project/Simple%20Calculator/Simple%20Calculator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        return "Error! Division by zero."
    return a / b

def modulus(a, b):
    if b == 0:
        return "Error! Division by zero."
    return a % b

def expo(a, b):
    return a ** b

while True:
    print("Simple Calculator")
    print("1. Addition")
    print("2. Subtraction")
    print("3. Multiplication")
    print("4. Division")
    print("5. Modulus")
    print("6. Exponential")
    print("7. Exit")

    choice = input("Choose an operation (1-5): ")

    if choice == '7':
        print("Exiting the calculator. Goodbye!")
        break  # Exit the loop

    if choice in ['1', '2', '3', '4','5','6']:
        num1 = float(input("Enter first number: "))
        num2 = float(input("Enter second number: "))

        if choice == '1':
            print("Result:", add(num1, num2))
        elif choice == '2':
            print("Result:", subtract(num1, num2))
        elif choice == '3':
            print("Result:", multiply(num1, num2))
        elif choice == '4':
            print("Result:", divide(num1, num2))
        elif choice == '5':
            print("Result:", modulus(num1, num2))
        elif choice == '6':
            print("Result:", expo(num1, num2))
    else:
        print("Invalid input! Please enter a number between 1 and 7.")
# Out:
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 1
# Enter first number: 20
# Enter second number: 40
# Result: 60.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 2
# Enter first number: 60
# Enter second number: 40
# Result: 20.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 3
# Enter first number: 60
# Enter second number: 2
# Result: 120.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 4
# Enter first number: 2400
# Enter second number: 6
# Result: 400.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 5
# Enter first number: 500
# Enter second number: 10
# Result: 0.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 6
# Enter first number: 2
# Enter second number: 10
# Result: 1024.0
# Simple Calculator
# 1. Addition
# 2. Subtraction
# 3. Multiplication
# 4. Division
# 5. Modulus
# 6. Exponential
# 7. Exit
# Choose an operation (1-5): 7
# Exiting the calculator. Goodbye!
