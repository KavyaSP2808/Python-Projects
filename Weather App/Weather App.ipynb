# %% [markdown]
# <a href="https://colab.research.google.com/github/KavyaSP2808/Python-Projects/blob/project/Weather%20App/Weather%20App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import requests

API_KEY = "ba4c42b094f07aab642201a8401b656e"
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

def get_weather(city):
    params = {
        "q": city,
        "appid": API_KEY,
        "units": "imperial"  # Use "imperial" for Fahrenheit # "metric" for Celsius
    }

    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        return {
            "city": data["name"],
            "temperature": data["main"]["temp"],
            "weather": data["weather"][0]["description"],
            "humidity": data["main"]["humidity"],
            "wind_speed": data["wind"]["speed"]
        }
    else:
        return None  # Return None if city is not found

# Example usage
city_name = input("Enter city name: ")
weather_data = get_weather(city_name)

if weather_data:
    print(f"Weather in {weather_data['city']}:")
    print(f"🌡️ Temperature: {weather_data['temperature']}°F")
    print(f"🌤️ Condition: {weather_data['weather'].title()}")
    print(f"💧 Humidity: {weather_data['humidity']}%")
    print(f"🌬️ Wind Speed: {weather_data['wind_speed']} m/s")
else:
    print("❌ City not found. Please try again.")
# Out:
# Enter city name: bangalore
# Weather in Bengaluru:
# 🌡️ Temperature: 75.4°F
# 🌤️ Condition: Few Clouds
# 💧 Humidity: 46%
# 🌬️ Wind Speed: 15.99 m/s

# %%
import requests

API_KEY = "ba4c42b094f07aab642201a8401b656e"
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

def get_weather_data(city):
    params = {
        "q": city,
        "appid": API_KEY,
        "units": "metric"
    }

    response = requests.get(BASE_URL, params=params)

    if response.status_code == 200:
        data = response.json()
        return {
            "city": data["name"],
            "temperature": data["main"]["temp"],
            "weather": data["weather"][0]["description"],
            "humidity": data["main"]["humidity"],
            "wind_speed": data["wind"]["speed"]
        }
    else:
        return None

city_name = input("Enter city name: ")
weather_result = get_weather_data(city_name)

if weather_result:
    print(f"Weather in {weather_result['city']}:")
    print(f"🌡️ Temperature: {weather_result['temperature']}°C")
    print(f"🌤️ Condition: {weather_result['weather'].title()}")
    print(f"💧 Humidity: {weather_result['humidity']}%")
    print(f"🌬️ Wind Speed: {weather_result['wind_speed']} m/s")
else:
    print("❌ City not found. Please try again.")
# Out:
# Enter city name: Karnataka
# Weather in Karnataka:
# 🌡️ Temperature: 24.13°C
# 🌤️ Condition: Broken Clouds
# 💧 Humidity: 42%
# 🌬️ Wind Speed: 1.24 m/s
